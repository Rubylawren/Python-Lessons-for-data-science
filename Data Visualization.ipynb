# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("big_mart_sales.csv")
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# **LINE CHART**

# %%
#mean price by item price
price_by_item = data.groupby("Item_Type").Item_MRP.mean()[:10]

# %%
x = price_by_item.index.tolist()
y = price_by_item.values.tolist()

plt.figure(figsize=(14, 8))
plt.title('Mean price for each item type')

plt.xlabel('Item Type')
plt.ylabel('mean price')

plt.plot(x, y, marker='o')

# %% [markdown]
# **BAR CHART**

# %%
#sales by outlet size
sales_by_outlet_size = data.groupby('Outlet_Size').Item_Outlet_Sales.mean()

#sort by sales
sales_by_outlet_size.sort_values(inplace=True)

x=sales_by_outlet_size.index.tolist()
y=sales_by_outlet_size.values.tolist()

#set axis labels
plt.xlabel("Outlet Size")
plt.ylabel("Sales")

#set title
plt.title("Mean sales for each outlet type")

plt.bar(x,y, color=['red', 'orange', 'magenta'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# **HISTOGRAM**

# %%
#title
plt.title("Item MRP (price distribution) ")

#xlabel
plt.xlabel("Item MRP")

#ylabel
plt.ylabel("Frequency")

#plot the histogram
plt.hist(data['Item_MRP'], bins=20, color='lightblue')
# Out:
# (array([451., 472., 415., 158., 477., 576., 620., 628., 295., 509., 580.,
#         518., 622., 578., 227., 253., 303., 254., 271., 316.]),
#  array([ 31.29   ,  43.06992,  54.84984,  66.62976,  78.40968,  90.1896 ,
#         101.96952, 113.74944, 125.52936, 137.30928, 149.0892 , 160.86912,
#         172.64904, 184.42896, 196.20888, 207.9888 , 219.76872, 231.54864,
#         243.32856, 255.10848, 266.8884 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# **BOX PLOT**

# %%
box_data = data['Item_Outlet_Sales']

#create outlier point shape
red_diamond = dict(markerfacecolor='r', marker='D')

#set title
plt.title('Item Sales Distribution')

#make the boxplot
plt.boxplot(box_data.values, labels=['Item Sales'], flierprops=red_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2516b066750>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2516b067f50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2516c1c1750>],
#  'medians': [<matplotlib.lines.Line2D at 0x2516b071510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2516b009f50>],
#  'means': []}

# %%
box_data = data[['Item_Weight', 'Item_MRP']]

red_diamond = dict(markerfacecolor='r', marker='D')

#geberate subplots
fig, ax = plt.subplots()

#make the boxplot
plt.boxplot(box_data.values, labels=['Item Weight', 'Item MRP (price)'], flierprops=red_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2516b0cf350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2516b0dcc10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2516b0ce7d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2516b0de2d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2516b02be50>,
# ...
#  'means': []}

# %% [markdown]
# **SEABORN**

# %%
import seaborn as sns
sns.set()
sns.set(style='darkgrid')

# %%
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=(10,10)

# %%
#lineplot using seaborn
sns.lineplot(x='Item_Weight', y='Item_MRP', data=data[:50])
# Out:
# <Axes: xlabel='Item_Weight', ylabel='Item_MRP'>

# %%
#barplot
sns.barplot(x='Item_Type', y='Item_MRP', data=data[:5])
# Out:
# <Axes: xlabel='Item_Type', ylabel='Item_MRP'>

# %%
sns.distplot(data['Item_MRP'], hist=False)
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Density'>

# %%
sns.boxplot(data['Item_Outlet_Sales'], orient='vertical')
# Out:
# <Axes: >

# %%
sns.violinplot(data['Item_Outlet_Sales'], prient='vertical', color='magenta')
# Out:
# <Axes: >

# %%
sns.relplot(x='Item_MRP', y='Item_Outlet_Sales', data=data[:200], kind='scatter')

# %% [markdown]
# **Category Scatterplots in Seaborn**

# %%
#strip plot
sns.catplot(x='Outlet_Size', y='Item_Outlet_Sales', kind='strip', data=data[:250])

# %%
#swarm plot
sns.catplot(x='Outlet_Size', y='Item_Outlet_Sales', kind='swarm', data=data[:250])

# %% [markdown]
# **Categorical Distribution Plots**

# %%
#box plots
sns.catplot(x='Outlet_Size', y='Item_Outlet_Sales', kind='box', data=data)

# %%
#violin plots
sns.catplot(x='Outlet_Size', y='Item_Outlet_Sales', kind='violin', data=data)

# %% [markdown]
# **Boxen Plots**

# %%
sns.catplot(x='Outlet_Size', y='Item_Outlet_Sales', kind='boxen', data=data)

# %%
#point plot
sns.catplot(x='Outlet_Size', y='Item_Outlet_Sales', kind='point', data=data)

# %%
#bar plot
sns.catplot(x='Outlet_Size', y='Item_Outlet_Sales', kind='bar', data=data)

# %%
#density plots
plt.figure(figsize=(10,10))
sns.kdeplot(data['Item_Visibility'], shade=True)
# Out:
# <Axes: xlabel='Item_Visibility', ylabel='Density'>

# %%
plt.figure(figsize=(10,10))
sns.kdeplot(data['Item_MRP'], shade = True)
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Density'>

# %%
#histograms
plt.figure(figsize=(10,10))
sns.distplot(data['Item_Outlet_Sales'])
# Out:
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>
